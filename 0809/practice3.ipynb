# %%
print("hello world")
# Out:
# hello world

# %%
print("double quot string")
# Out:
# double quot string

# %%
print('double quot string')
# Out:
# double quot string

# %%
print(50)
print(50.5)
print(True)
print(False)
# Out:
# 50
# 50.5
# True
# False

# %%
var1 = "string1"
var2 = "string2'"
var3 = 12.5
var4 = 123
var5 = True

print(var1 + " " + var2)
print(type(var1), type(var3), type(var4), type(var5), )
# Out:
# string1 string2'
# <class 'str'> <class 'float'> <class 'int'> <class 'bool'>

# %%
1+1
# Out:
# 2

# %%
(1+1)*5
# Out:
# 10

# %%
(1+3)*5
# Out:
# 20

# %%
5+5
# Out:
# 10

# %%
inval = int(input("enter an integer . "))
print(inval)
# Out:
# enter an integer .  123
# 123

# %%
diameter = input("enter diameter")
# Out:
# enter diameter 12

# %%
diameter = float(input("enter your diameter in cm"))
print("area ", 3.14*diameter**2, "cm2")
# Out:
# enter your diameter in cm 2
# area  12.56 cm2
